# %%
#libraries that we might need
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Activation
import pandas as pd
import tensorflow
import io
import os
import requests
import numpy as np
from sklearn import metrics
from sklearn.model_selection import train_test_split
import math
from math import log
import numpy as np 
import matplotlib 
import matplotlib.pyplot as plt

# %%
domain = []
for i in range(0,800):
  domain.append(i/1000)
test_domain = []
for i in range(800,1001):
  test_domain.append(i/1000)

# %%
def timeseries(f):
  series = []
  for i in domain:
    series.append(f(i))
  return series

# %%
seed = 3

#returns the RMSE, percent of variance explained and the L2 norm of the data
def function_info (function):
  #model for the data
  tensorflow.random.set_seed(seed)
  model1 = Sequential()
  model1.add(Dense(3000, input_dim=1, activation='relu')) # Hidden 1
  model1.add(Dense(1500, activation='relu')) # Hidden 2
  model1.add(Dense(1)) # Output
  model1.compile(loss='mean_squared_error', optimizer='adam')
  #fits the model based on the input function
  model1.fit(domain,timeseries(function),verbose=2,epochs=16)


  #processes the data for the model

  pred1 = model1.predict(test_domain)
  y1 = np.array(list(map(function, test_domain)))
  score1 = np.sqrt(metrics.mean_squared_error(pred1, y1))
  pvariance1 = (y1.std()-score1)/y1.std()
  
  #calculates the l2 norm

  sum = 0
  n = len(y1)
  for i in range (n-1):
    sum += (y1[i+1]-y1[i])**2

  sum = sum/n

  sum = np.sqrt(sum)

  return score1, pvariance1, sum

# %%
function_array = []

for i in range(1,11):
  f = lambda x, i=i : (np.sin(1/x))*(x**(1+(1/i))) if x!=0 else 0
  function_array.append(f)

for i in function_array:
  print(i(1/2))
# Out:
# 0.22732435670642043
# 0.32148518831195905
# 0.36085492297376603
# 0.38231247330857127
# 0.3957946935634067
# 0.4050459559836544
# 0.41178609866514904
# 0.4169147084373769
# 0.42094774672290075
# 0.4242022491739435

# %%
all_those_results = np.array(list(map(function_info, function_array)))
all_those_results
# Out:
# Epoch 1/16
# 25/25 - 3s - loss: 0.0103 - 3s/epoch - 109ms/step
# Epoch 2/16
# 25/25 - 0s - loss: 3.8496e-04 - 60ms/epoch - 2ms/step
# Epoch 3/16
# 25/25 - 0s - loss: 6.8042e-05 - 60ms/epoch - 2ms/step
# Epoch 4/16
# 25/25 - 0s - loss: 2.5393e-05 - 64ms/epoch - 3ms/step
# Epoch 5/16
# 25/25 - 0s - loss: 1.7895e-05 - 62ms/epoch - 2ms/step
# Epoch 6/16
# 25/25 - 0s - loss: 1.4335e-05 - 63ms/epoch - 3ms/step
# Epoch 7/16
# 25/25 - 0s - loss: 1.3128e-05 - 65ms/epoch - 3ms/step
# Epoch 8/16
# 25/25 - 0s - loss: 1.2337e-05 - 65ms/epoch - 3ms/step
# Epoch 9/16
# 25/25 - 0s - loss: 1.1605e-05 - 61ms/epoch - 2ms/step
# Epoch 10/16
# 25/25 - 0s - loss: 1.0849e-05 - 58ms/epoch - 2ms/step
# Epoch 11/16
# 25/25 - 0s - loss: 1.0306e-05 - 63ms/epoch - 3ms/step
# Epoch 12/16
# 25/25 - 0s - loss: 9.9568e-06 - 65ms/epoch - 3ms/step
# Epoch 13/16
# 25/25 - 0s - loss: 9.7114e-06 - 64ms/epoch - 3ms/step
# Epoch 14/16
# 25/25 - 0s - loss: 9.6071e-06 - 59ms/epoch - 2ms/step
# Epoch 15/16
# 25/25 - 0s - loss: 9.5605e-06 - 58ms/epoch - 2ms/step
# Epoch 16/16
# 25/25 - 0s - loss: 9.5519e-06 - 68ms/epoch - 3ms/step
# Epoch 1/16
# 25/25 - 0s - loss: 0.0134 - 305ms/epoch - 12ms/step
# Epoch 2/16
# 25/25 - 0s - loss: 0.0013 - 59ms/epoch - 2ms/step
# Epoch 3/16
# 25/25 - 0s - loss: 6.6410e-04 - 67ms/epoch - 3ms/step
# Epoch 4/16
# 25/25 - 0s - loss: 4.3264e-04 - 60ms/epoch - 2ms/step
# Epoch 5/16
# 25/25 - 0s - loss: 2.5069e-04 - 62ms/epoch - 2ms/step
# Epoch 6/16
# 25/25 - 0s - loss: 1.7204e-04 - 59ms/epoch - 2ms/step
# Epoch 7/16
# 25/25 - 0s - loss: 1.5203e-04 - 61ms/epoch - 2ms/step
# Epoch 8/16
# 25/25 - 0s - loss: 1.3657e-04 - 60ms/epoch - 2ms/step
# Epoch 9/16
# 25/25 - 0s - loss: 1.2654e-04 - 57ms/epoch - 2ms/step
# Epoch 10/16
# 25/25 - 0s - loss: 1.1445e-04 - 57ms/epoch - 2ms/step
# Epoch 11/16
# 25/25 - 0s - loss: 1.0951e-04 - 59ms/epoch - 2ms/step
# Epoch 12/16
# 25/25 - 0s - loss: 1.0429e-04 - 56ms/epoch - 2ms/step
# Epoch 13/16
# 25/25 - 0s - loss: 1.0467e-04 - 56ms/epoch - 2ms/step
# Epoch 14/16
# 25/25 - 0s - loss: 1.0735e-04 - 65ms/epoch - 3ms/step
# Epoch 15/16
# 25/25 - 0s - loss: 1.0536e-04 - 58ms/epoch - 2ms/step
# Epoch 16/16
# 25/25 - 0s - loss: 9.6081e-05 - 78ms/epoch - 3ms/step
# Epoch 1/16
# 25/25 - 0s - loss: 0.0156 - 327ms/epoch - 13ms/step
# Epoch 2/16
# 25/25 - 0s - loss: 0.0021 - 57ms/epoch - 2ms/step
# Epoch 3/16
# 25/25 - 0s - loss: 0.0013 - 60ms/epoch - 2ms/step
# Epoch 4/16
# 25/25 - 0s - loss: 8.5719e-04 - 71ms/epoch - 3ms/step
# Epoch 5/16
# 25/25 - 0s - loss: 5.2254e-04 - 60ms/epoch - 2ms/step
# Epoch 6/16
# 25/25 - 0s - loss: 3.8830e-04 - 79ms/epoch - 3ms/step
# Epoch 7/16
# 25/25 - 0s - loss: 3.3141e-04 - 63ms/epoch - 3ms/step
# Epoch 8/16
# 25/25 - 0s - loss: 2.9436e-04 - 61ms/epoch - 2ms/step
# Epoch 9/16
# 25/25 - 0s - loss: 2.5207e-04 - 58ms/epoch - 2ms/step
# Epoch 10/16
# 25/25 - 0s - loss: 2.2213e-04 - 58ms/epoch - 2ms/step
# Epoch 11/16
# 25/25 - 0s - loss: 2.1056e-04 - 68ms/epoch - 3ms/step
# Epoch 12/16
# 25/25 - 0s - loss: 2.0917e-04 - 62ms/epoch - 2ms/step
# Epoch 13/16
# 25/25 - 0s - loss: 2.0970e-04 - 64ms/epoch - 3ms/step
# Epoch 14/16
# 25/25 - 0s - loss: 2.0759e-04 - 64ms/epoch - 3ms/step
# Epoch 15/16
# 25/25 - 0s - loss: 1.9559e-04 - 62ms/epoch - 2ms/step
# Epoch 16/16
# 25/25 - 0s - loss: 1.7448e-04 - 60ms/epoch - 2ms/step
# Epoch 1/16
# 25/25 - 0s - loss: 0.0170 - 341ms/epoch - 14ms/step
# Epoch 2/16
# 25/25 - 0s - loss: 0.0027 - 66ms/epoch - 3ms/step
# Epoch 3/16
# 25/25 - 0s - loss: 0.0017 - 66ms/epoch - 3ms/step
# Epoch 4/16
# 25/25 - 0s - loss: 0.0011 - 61ms/epoch - 2ms/step
# Epoch 5/16
# 25/25 - 0s - loss: 7.0212e-04 - 60ms/epoch - 2ms/step
# Epoch 6/16
# 25/25 - 0s - loss: 5.8351e-04 - 62ms/epoch - 2ms/step
# Epoch 7/16
# 25/25 - 0s - loss: 5.0282e-04 - 67ms/epoch - 3ms/step
# Epoch 8/16
# 25/25 - 0s - loss: 3.9223e-04 - 61ms/epoch - 2ms/step
# Epoch 9/16
# 25/25 - 0s - loss: 3.5059e-04 - 64ms/epoch - 3ms/step
# Epoch 10/16
# 25/25 - 0s - loss: 3.2770e-04 - 61ms/epoch - 2ms/step
# Epoch 11/16
# 25/25 - 0s - loss: 3.1243e-04 - 63ms/epoch - 3ms/step
# Epoch 12/16
# 25/25 - 0s - loss: 2.8923e-04 - 63ms/epoch - 3ms/step
# Epoch 13/16
# 25/25 - 0s - loss: 2.5891e-04 - 66ms/epoch - 3ms/step
# Epoch 14/16
# 25/25 - 0s - loss: 2.4055e-04 - 66ms/epoch - 3ms/step
# Epoch 15/16
# 25/25 - 0s - loss: 2.3950e-04 - 64ms/epoch - 3ms/step
# Epoch 16/16
# 25/25 - 0s - loss: 2.4128e-04 - 64ms/epoch - 3ms/step
# Epoch 1/16
# 25/25 - 0s - loss: 0.0180 - 333ms/epoch - 13ms/step
# Epoch 2/16
# 25/25 - 0s - loss: 0.0032 - 61ms/epoch - 2ms/step
# Epoch 3/16
# 25/25 - 0s - loss: 0.0020 - 58ms/epoch - 2ms/step
# Epoch 4/16
# 25/25 - 0s - loss: 0.0013 - 63ms/epoch - 3ms/step
# Epoch 5/16
# 25/25 - 0s - loss: 8.8546e-04 - 63ms/epoch - 3ms/step
# Epoch 6/16
# 25/25 - 0s - loss: 7.3918e-04 - 63ms/epoch - 3ms/step
# Epoch 7/16
# 25/25 - 0s - loss: 6.0454e-04 - 63ms/epoch - 3ms/step
# Epoch 8/16
# 25/25 - 0s - loss: 4.6579e-04 - 62ms/epoch - 2ms/step
# Epoch 9/16
# 25/25 - 0s - loss: 4.1704e-04 - 65ms/epoch - 3ms/step
# Epoch 10/16
# 25/25 - 0s - loss: 3.9618e-04 - 62ms/epoch - 2ms/step
# Epoch 11/16
# 25/25 - 0s - loss: 3.8116e-04 - 70ms/epoch - 3ms/step
# Epoch 12/16
# 25/25 - 0s - loss: 3.4784e-04 - 68ms/epoch - 3ms/step
# Epoch 13/16
# 25/25 - 0s - loss: 3.0857e-04 - 65ms/epoch - 3ms/step
# Epoch 14/16
# 25/25 - 0s - loss: 2.9089e-04 - 60ms/epoch - 2ms/step
# Epoch 15/16
# 25/25 - 0s - loss: 2.9340e-04 - 61ms/epoch - 2ms/step
# Epoch 16/16
# 25/25 - 0s - loss: 3.0256e-04 - 66ms/epoch - 3ms/step
# Epoch 1/16
# 25/25 - 0s - loss: 0.0187 - 328ms/epoch - 13ms/step
# Epoch 2/16
# 25/25 - 0s - loss: 0.0035 - 60ms/epoch - 2ms/step
# Epoch 3/16
# 25/25 - 0s - loss: 0.0022 - 58ms/epoch - 2ms/step
# Epoch 4/16
# 25/25 - 0s - loss: 0.0014 - 65ms/epoch - 3ms/step
# Epoch 5/16
# 25/25 - 0s - loss: 0.0010 - 63ms/epoch - 3ms/step
# Epoch 6/16
# 25/25 - 0s - loss: 8.8700e-04 - 66ms/epoch - 3ms/step
# Epoch 7/16
# 25/25 - 0s - loss: 6.8133e-04 - 64ms/epoch - 3ms/step
# Epoch 8/16
# 25/25 - 0s - loss: 5.2264e-04 - 60ms/epoch - 2ms/step
# Epoch 9/16
# 25/25 - 0s - loss: 4.6795e-04 - 70ms/epoch - 3ms/step
# Epoch 10/16
# 25/25 - 0s - loss: 4.4556e-04 - 61ms/epoch - 2ms/step
# Epoch 11/16
# 25/25 - 0s - loss: 4.1396e-04 - 61ms/epoch - 2ms/step
# Epoch 12/16
# 25/25 - 0s - loss: 3.7283e-04 - 62ms/epoch - 2ms/step
# Epoch 13/16
# 25/25 - 0s - loss: 3.4183e-04 - 60ms/epoch - 2ms/step
# Epoch 14/16
# 25/25 - 0s - loss: 3.3705e-04 - 60ms/epoch - 2ms/step
# Epoch 15/16
# 25/25 - 0s - loss: 3.4091e-04 - 62ms/epoch - 2ms/step
# Epoch 16/16
# 25/25 - 0s - loss: 3.6993e-04 - 59ms/epoch - 2ms/step
# Epoch 1/16
# 25/25 - 0s - loss: 0.0193 - 328ms/epoch - 13ms/step
# Epoch 2/16
# 25/25 - 0s - loss: 0.0038 - 62ms/epoch - 2ms/step
# Epoch 3/16
# 25/25 - 0s - loss: 0.0024 - 59ms/epoch - 2ms/step
# Epoch 4/16
# 25/25 - 0s - loss: 0.0015 - 60ms/epoch - 2ms/step
# Epoch 5/16
# 25/25 - 0s - loss: 0.0012 - 60ms/epoch - 2ms/step
# Epoch 6/16
# 25/25 - 0s - loss: 9.8733e-04 - 61ms/epoch - 2ms/step
# Epoch 7/16
# 25/25 - 0s - loss: 7.5799e-04 - 64ms/epoch - 3ms/step
# Epoch 8/16
# 25/25 - 0s - loss: 5.7367e-04 - 66ms/epoch - 3ms/step
# Epoch 9/16
# 25/25 - 0s - loss: 5.1383e-04 - 63ms/epoch - 3ms/step
# Epoch 10/16
# 25/25 - 0s - loss: 4.9230e-04 - 59ms/epoch - 2ms/step
# Epoch 11/16
# 25/25 - 0s - loss: 4.6437e-04 - 59ms/epoch - 2ms/step
# Epoch 12/16
# 25/25 - 0s - loss: 4.2161e-04 - 60ms/epoch - 2ms/step
# Epoch 13/16
# 25/25 - 0s - loss: 3.8749e-04 - 60ms/epoch - 2ms/step
# Epoch 14/16
# 25/25 - 0s - loss: 3.7426e-04 - 61ms/epoch - 2ms/step
# Epoch 15/16
# 25/25 - 0s - loss: 3.7630e-04 - 63ms/epoch - 3ms/step
# Epoch 16/16
# 25/25 - 0s - loss: 4.1205e-04 - 61ms/epoch - 2ms/step
# Epoch 1/16
# 25/25 - 1s - loss: 0.0198 - 508ms/epoch - 20ms/step
# Epoch 2/16
# 25/25 - 0s - loss: 0.0040 - 61ms/epoch - 2ms/step
# Epoch 3/16
# 25/25 - 0s - loss: 0.0025 - 57ms/epoch - 2ms/step
# Epoch 4/16
# 25/25 - 0s - loss: 0.0016 - 60ms/epoch - 2ms/step
# Epoch 5/16
# 25/25 - 0s - loss: 0.0012 - 61ms/epoch - 2ms/step
# Epoch 6/16
# 25/25 - 0s - loss: 0.0011 - 61ms/epoch - 2ms/step
# Epoch 7/16
# 25/25 - 0s - loss: 8.0619e-04 - 63ms/epoch - 3ms/step
# Epoch 8/16
# 25/25 - 0s - loss: 6.0630e-04 - 62ms/epoch - 2ms/step
# Epoch 9/16
# 25/25 - 0s - loss: 5.4740e-04 - 60ms/epoch - 2ms/step
# Epoch 10/16
# 25/25 - 0s - loss: 5.2975e-04 - 61ms/epoch - 2ms/step
# Epoch 11/16
# 25/25 - 0s - loss: 4.9915e-04 - 61ms/epoch - 2ms/step
# Epoch 12/16
# 25/25 - 0s - loss: 4.5348e-04 - 62ms/epoch - 2ms/step
# Epoch 13/16
# 25/25 - 0s - loss: 4.1744e-04 - 60ms/epoch - 2ms/step
# Epoch 14/16
# 25/25 - 0s - loss: 4.0269e-04 - 59ms/epoch - 2ms/step
# Epoch 15/16
# 25/25 - 0s - loss: 3.9533e-04 - 62ms/epoch - 2ms/step
# Epoch 16/16
# 25/25 - 0s - loss: 4.0477e-04 - 61ms/epoch - 2ms/step
# Epoch 1/16
# 25/25 - 0s - loss: 0.0201 - 323ms/epoch - 13ms/step
# Epoch 2/16
# 25/25 - 0s - loss: 0.0042 - 61ms/epoch - 2ms/step
# Epoch 3/16
# 25/25 - 0s - loss: 0.0026 - 58ms/epoch - 2ms/step
# Epoch 4/16
# 25/25 - 0s - loss: 0.0017 - 60ms/epoch - 2ms/step
# Epoch 5/16
# 25/25 - 0s - loss: 0.0013 - 66ms/epoch - 3ms/step
# Epoch 6/16
# 25/25 - 0s - loss: 0.0011 - 60ms/epoch - 2ms/step
# Epoch 7/16
# 25/25 - 0s - loss: 8.5605e-04 - 59ms/epoch - 2ms/step
# Epoch 8/16
# 25/25 - 0s - loss: 6.4311e-04 - 68ms/epoch - 3ms/step
# Epoch 9/16
# 25/25 - 0s - loss: 5.8482e-04 - 70ms/epoch - 3ms/step
# Epoch 10/16
# 25/25 - 0s - loss: 5.6946e-04 - 59ms/epoch - 2ms/step
# Epoch 11/16
# 25/25 - 0s - loss: 5.3197e-04 - 58ms/epoch - 2ms/step
# Epoch 12/16
# 25/25 - 0s - loss: 4.7624e-04 - 60ms/epoch - 2ms/step
# Epoch 13/16
# 25/25 - 0s - loss: 4.3499e-04 - 63ms/epoch - 3ms/step
# Epoch 14/16
# 25/25 - 0s - loss: 4.1271e-04 - 62ms/epoch - 2ms/step
# Epoch 15/16
# 25/25 - 0s - loss: 4.0609e-04 - 62ms/epoch - 2ms/step
# Epoch 16/16
# 25/25 - 0s - loss: 4.5620e-04 - 64ms/epoch - 3ms/step
# Epoch 1/16
# 25/25 - 0s - loss: 0.0204 - 322ms/epoch - 13ms/step
# Epoch 2/16
# 25/25 - 0s - loss: 0.0043 - 58ms/epoch - 2ms/step
# Epoch 3/16
# 25/25 - 0s - loss: 0.0028 - 60ms/epoch - 2ms/step
# Epoch 4/16
# 25/25 - 0s - loss: 0.0018 - 56ms/epoch - 2ms/step
# Epoch 5/16
# 25/25 - 0s - loss: 0.0014 - 61ms/epoch - 2ms/step
# Epoch 6/16
# 25/25 - 0s - loss: 0.0012 - 57ms/epoch - 2ms/step
# Epoch 7/16
# 25/25 - 0s - loss: 8.9258e-04 - 58ms/epoch - 2ms/step
# Epoch 8/16
# 25/25 - 0s - loss: 6.6533e-04 - 60ms/epoch - 2ms/step
# Epoch 9/16
# 25/25 - 0s - loss: 5.9834e-04 - 60ms/epoch - 2ms/step
# Epoch 10/16
# 25/25 - 0s - loss: 5.6709e-04 - 61ms/epoch - 2ms/step
# Epoch 11/16
# 25/25 - 0s - loss: 5.2860e-04 - 69ms/epoch - 3ms/step
# Epoch 12/16
# 25/25 - 0s - loss: 4.7785e-04 - 62ms/epoch - 2ms/step
# Epoch 13/16
# 25/25 - 0s - loss: 4.4536e-04 - 59ms/epoch - 2ms/step
# Epoch 14/16
# 25/25 - 0s - loss: 4.3145e-04 - 59ms/epoch - 2ms/step
# Epoch 15/16
# 25/25 - 0s - loss: 4.2706e-04 - 58ms/epoch - 2ms/step
# Epoch 16/16
# 25/25 - 0s - loss: 4.6864e-04 - 61ms/epoch - 2ms/step
# array([[ 1.78554314e-02,  7.37024837e-01,  1.16781785e-03],
#        [ 5.11866789e-02, -8.80637244e-02,  8.12144048e-04],
#        [ 6.43462174e-02, -6.26414754e-01,  6.84911854e-04],
#        [ 7.27464484e-02, -1.03664281e+00,  6.19586555e-04],
#        [ 7.50715479e-02, -1.24911574e+00,  5.79838875e-04],
#        [ 7.82033457e-02, -1.45894381e+00,  5.53110150e-04],
#        [ 7.87803415e-02, -1.56848642e+00,  5.33905755e-04],
#        [ 6.87889394e-02, -1.30686409e+00,  5.19441214e-04],
#        [ 7.80851140e-02, -1.67838681e+00,  5.08154879e-04],
#        [ 7.79162466e-02, -1.72244250e+00,  4.99103143e-04]])

# %%
loss = []
var = []
for i in all_those_results:
  rmse, pove, l2 = i
  loss.append(rmse)
  var.append(l2)

nploss = np.array(loss)
npvar = np.array(var)

plt.scatter(npvar,nploss)
a, b = np.polyfit(npvar, nploss, 1)
plt.plot(npvar, a*npvar + b)
plt.xlabel("Complexity")
plt.ylabel("Loss of the model")
plt.show()
